# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\Amal\AppData\Local\Temp\ipykernel_10900\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': '| Version | Release date | Status | Description |\n| GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |\n| GPT-4 | March 2023 | Discontinued | Introduced in March 2023. |\n| GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. |\n| GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |\n| o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an updated version that could "think" before responding to requests. |\n| o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller and cheaper version of GPT-4.1. Originally launched exclusively in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |\n| o3 | April 2025 | Legacy support | The full release of the o3 model, emphasizing structured reasoning and faster performance compared to earlier "o" series models |\n| o4-mini | April 2025 | Discontinued | A compact, high-efficiency version of the upcoming o4 model family, optimized for lower latency and lighter compute requirements. |\n| o4-mini-high | April 2025 | Discontinued | Variant of o4-mini using more reasoning effort. |\n| o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. | [...] | GPT-5 | August 7, 2025 | Discontinued | Flagship model replacing all previous available models. The versions GPT-5 Instant, GPT-5 Thinking and GPT-5 Pro affect the reasoning time. The default version GPT-5 Auto uses a router to determine how much reasoning is needed, based on the complexity of the request. |\n| GPT-5 mini | August 7, 2025 | Legacy support | Faster, more cost-efficient version of GPT-5. |\n| GPT-5.1 | November 12, 2025 | Legacy support | Warmer and better at following instructions according to OpenAI. Allows users to select alternative personalities. |\n| GPT-5.2 | December 11, 2025 | Active |\n| GPT-5.3-Codex | February 05, 2026 | Active |  |',
#   'score': 0.9998894},
#  {'title': 'ChatGPT by OpenAI - Release Notes - February 2026 Latest Updates',
#   'url': 'https://releasebot.io/updates/openai/chatgpt',
#   'content': 'ChatGPT by OpenAI\n\n  ## February 13, 2026\n\n  OpenAI retires GPT-4o and legacy models and rolls out ChatGPT updates. Users get up to 20-file uploads, broader file type support, cleaner copy via Cmd+A, quick tools on Android, a simplified composer, faster iOS performance, and steadier long chats.\n\n  ### Retiring GPT-4o and other legacy models\n\n  As previously announced, we have retired GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini from ChatGPT. We are also retiring GPT-5 (Instant and Thinking), as previously announced. There are no API changes at this time. For details, see our blog post and Help Center.\n\n  ### ChatGPT updates: Better file uploads, easier copying, and more reliable long chats\n\n  Web [...] Users should notice responses that are more measured and grounded in tone, in a way that’s more contextually appropriate to the conversation. The model also tends to output clearer, more relevant answers to advice-seeking and how-to questions, more reliably placing the most important info upfront.\n\n  Original source  Report a problem\n Feb 9, 2026 \n  + Date parsed from source:\n\n    Feb 9, 2026\n  + First seen by Releasebot:\n\n    Feb 10, 2026\n\n  ChatGPT by OpenAI\n\n  ## February 9, 2026\n\n  ChatGPT starts a US ad test for logged-in Free and Go users while paid plans stay ad-free. Ads are clearly labeled with user privacy controls, and you can dismiss, delete ad data, or adjust personalization. Rollout is gradual and excludes sensitive topics.\n\n  ### Ads in ChatGPT test rollout [...] A redesigned sidebar entry point and fullscreen report view make it easier to start, review, and manage research in one place. Create and edit a research plan before it begins, and track progress with the ability to adjust direction mid-run.\n\n  Rolling out throughout today to Plus and Pro users, with Free and Go users following in the coming days.\n\n  For more information, please refer to our help center article:  \n  Deep research in ChatGPT\n\n  ### GPT-5.2 Instant Update\n\n  We’re making an update to GPT-5.2 Instant in ChatGPT and the API that improves response style and quality.',
#   'score': 0.99961406}]

# %%
for r in results:
    print(r['content'])
# Out:
# | Version | Release date | Status | Description |
# | GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT. |
# | GPT-4 | March 2023 | Discontinued | Introduced in March 2023. |
# | GPT-4o | May 2024 | Discontinued | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4. |
# | GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT. |
# | o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an updated version that could "think" before responding to requests. |
# | o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1. | [...] | GPT-4.1 mini | April 2025 | Discontinued | A smaller and cheaper version of GPT-4.1. Originally launched exclusively in the OpenAI API in April 2025. GPT-4.1 mini replaced GPT-4o mini in the May 2025 version of ChatGPT. |
# | o3 | April 2025 | Legacy support | The full release of the o3 model, emphasizing structured reasoning and faster performance compared to earlier "o" series models |
# | o4-mini | April 2025 | Discontinued | A compact, high-efficiency version of the upcoming o4 model family, optimized for lower latency and lighter compute requirements. |
# | o4-mini-high | April 2025 | Discontinued | Variant of o4-mini using more reasoning effort. |
# | o3-pro | June 2025 | Discontinued | A version of o3 which uses more compute to get better results. | [...] | GPT-5 | August 7, 2025 | Discontinued | Flagship model replacing all previous available models. The versions GPT-5 Instant, GPT-5 Thinking and GPT-5 Pro affect the reasoning time. The default version GPT-5 Auto uses a router to determine how much reasoning is needed, based on the complexity of the request. |
# | GPT-5 mini | August 7, 2025 | Legacy support | Faster, more cost-efficient version of GPT-5. |
# | GPT-5.1 | November 12, 2025 | Legacy support | Warmer and better at following instructions according to OpenAI. Allows users to select alternative personalities. |
# | GPT-5.2 | December 11, 2025 | Active |
# | GPT-5.3-Codex | February 05, 2026 | Active |  |
# ChatGPT by OpenAI
#
#   ## February 13, 2026
#
#   OpenAI retires GPT-4o and legacy models and rolls out ChatGPT updates. Users get up to 20-file uploads, broader file type support, cleaner copy via Cmd+A, quick tools on Android, a simplified composer, faster iOS performance, and steadier long chats.
#
#   ### Retiring GPT-4o and other legacy models
#
#   As previously announced, we have retired GPT-4o, GPT-4.1, GPT-4.1 mini, and OpenAI o4-mini from ChatGPT. We are also retiring GPT-5 (Instant and Thinking), as previously announced. There are no API changes at this time. For details, see our blog post and Help Center.
#
#   ### ChatGPT updates: Better file uploads, easier copying, and more reliable long chats
#
#   Web [...] Users should notice responses that are more measured and grounded in tone, in a way that’s more contextually appropriate to the conversation. The model also tends to output clearer, more relevant answers to advice-seeking and how-to questions, more reliably placing the most important info upfront.
#
#   Original source  Report a problem
#  Feb 9, 2026
#   + Date parsed from source:
#
#     Feb 9, 2026
#   + First seen by Releasebot:
#
#     Feb 10, 2026
#
#   ChatGPT by OpenAI
#
#   ## February 9, 2026
#
#   ChatGPT starts a US ad test for logged-in Free and Go users while paid plans stay ad-free. Ads are clearly labeled with user privacy controls, and you can dismiss, delete ad data, or adjust personalization. Rollout is gradual and excludes sensitive topics.
#
#   ### Ads in ChatGPT test rollout [...] A redesigned sidebar entry point and fullscreen report view make it easier to start, review, and manage research in one place. Create and edit a research plan before it begins, and track progress with the ability to adjust direction mid-run.
#
#   Rolling out throughout today to Plus and Pro users, with Free and Go users following in the coming days.
#
#   For more information, please refer to our help center article:
#   Deep research in ChatGPT
#
#   ### GPT-5.2 Instant Update
#
#   We’re making an update to GPT-5.2 Instant in ChatGPT and the API that improves response style and quality.
